# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-Kharitonov/Python/blob/main/H.W.%239.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df[df['median_income'] < 2][['median_house_value']]
# Out:
#       median_house_value
# 5                67000.0
# 6                67000.0
# 16              181300.0
# 28              350000.0
# 43               79300.0
# ...                  ...
# 2943             57200.0
# 2964             91300.0
# 2985            109400.0
# 2986             85400.0
# 2995            225000.0
#
# [360 rows x 1 columns]

# %%
df[['longitude','latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
print(df['median_house_value'].max())
# Out:
# 500001.0

# %%
print(df['median_house_value'].min())
# Out:
# 22500.0

# %%
df[df['median_income'] == 3.1250].median_house_value.max()
# Out:
# 233300.0

# %%
min_house = df.median_house_value.min()
df[df['median_house_value'] == min_house].population.max()
# Out:
# 1230.0
